# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Import the data
df = pd.read_csv('hankel_error_rank_data_bench_fid_seed42.csv')

# %% [markdown]
# ## Error numerical experiment

# %% [markdown]
# Data filtering

# %%
error_df=df[['omega','eps','err','err0','err1','err2','err3','err4']]
error_df['eps_self'] = error_df['eps']

# Define new labels for the plot
label_map = {
    'err': '$SVD_{{gesdd}}$',
    'err0': '$HASVD_{{dist}}$',
    'err1': '$HASVD_{{inc}}$',
    'err2': '$HASVD_{{TLBD}}$',
    'err3': '$HASVD_{{TLBI}}$',
    'err4': '$HASVD_{{TLAI}}$',
    'eps_self': 'Reference'
}
# Out:
# /tmp/ipykernel_115763/2606198139.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   error_df['eps_self'] = error_df['eps']

# %%
rank_df=df[['omega','eps','r','r0','r1','r2','r3','r4', 'r_true']]

# Define new labels for the plot
label_map_2 = {
    'r': '$SVD_{{gesdd}}$',
    'r0': '$HASVD_{{dist}}$',
    'r1': '$HASVD_{{inc}}$',
    'r2': '$HASVD_{{TLBD}}$',
    'r3': '$HASVD_{{TLBI}}$',
    'r4': '$HASVD_{{TLAI}}$',
    'r_true': 'Reference'
}

# %% [markdown]
# Code

# %%
import matplotlib.pyplot as plt
import numpy as np

# Figure size in inches
width_in = 150 / 25.4  # 150 mm
height_in = width_in * 0.75+0.5  # 4:3 ratio

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": 10,
    "axes.labelsize": 10,
    "legend.fontsize": 8,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "figure.dpi": 300,
})

fig, axs = plt.subplots(2, 2, figsize=(width_in, height_in))
(ax1, ax2), (ax3, ax4) = axs

# Plot styles
markers = ['o', 's', 'd', 's', 'd','p', '*']
colors = ['k', 'g', 'r', 'c', 'm','b', 'k']
linestyles = ['-', ':', ':', '-.', '-.', ':','--']
xlim = [1, 1e-15]
xlabel = r'Prescribed relative error $\epsilon^*$'
ylabel_error = '$\langle\|A-U\Sigma V^T\|_F/\|A\|_F\\rangle$'
ylabel_rank = '$\langle\\mathrm{rank}(U\Sigma V^T)\\rangle$'

# Plot error (top row)
for ax, omega in [(ax1, 0.1), (ax2, 0.9)]:
    for i, col in enumerate(['err', 'err0', 'err1', 'err2', 'err3','err4', 'eps_self']):
        marker = None if col == 'eps_self' else markers[i % len(markers)]
        error_df[error_df["omega"] == omega].plot(
            x='eps', y=col, ax=ax,
            label=label_map[col],
            color=colors[i], linestyle=linestyles[i],
            marker=marker
        )
    ax.set_title(rf"$\omega={omega}$")
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlim(xlim)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel_error)
    ax.get_legend().remove()

# Plot rank (bottom row)
for ax, omega in [(ax3, 0.1), (ax4, 0.9)]:
    for i, col in enumerate(['r', 'r0', 'r1', 'r2', 'r3','r4', 'r_true']):
        marker = None if col == 'r_true' else markers[i % len(markers)]
        rank_df[rank_df["omega"] == omega].plot(
            x='eps', y=col, ax=ax,
            label=label_map_2[col],
            color=colors[i], linestyle=linestyles[i],
            marker=marker
        )
    ax.set_title(rf"$\omega={omega}$")
    ax.set_xscale('log')
    ax.set_xlim(xlim)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel_rank)
    ax.get_legend().remove()

# Shared legend above all plots
handles, labels = ax1.get_legend_handles_labels()


# Adjust layout
fig.tight_layout()
fig.subplots_adjust(top=0.85)  # Leave room for legend
fig.legend(handles, labels, loc='upper center', ncol=3, bbox_to_anchor=(0.5, 1.01))

# Save figure
fig.savefig("hankel-error-rank-fid42.pdf", format="pdf", dpi=300, transparent=True)
# fig.savefig("hankel-error-rank-fid.pgf")  # Optional

plt.close(fig)
# Out:
# <>:28: SyntaxWarning: invalid escape sequence '\l'
# <>:29: SyntaxWarning: invalid escape sequence '\l'
# <>:28: SyntaxWarning: invalid escape sequence '\l'
# <>:29: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_115763/2029385458.py:28: SyntaxWarning: invalid escape sequence '\l'
#   ylabel_error = '$\langle\|A-U\Sigma V^T\|_F/\|A\|_F\\rangle$'
# /tmp/ipykernel_115763/2029385458.py:29: SyntaxWarning: invalid escape sequence '\l'
#   ylabel_rank = '$\langle\\mathrm{rank}(U\Sigma V^T)\\rangle$'

# %%
# Import the data
df = pd.read_csv('hankel_error_rank_data_bench_lrf_seed42.csv')

# %%
error_df=df[['omega','eps','err','err0','err1','err2','err3','err4']]
error_df['eps_self'] = error_df['eps']

# Define new labels for the plot
label_map = {
    'err': '$SVD_{{gesdd}}$',
    'err0': '$HASVD_{{dist}}$',
    'err1': '$HASVD_{{inc}}$',
    'err2': '$HASVD_{{TLBD}}$',
    'err3': '$HASVD_{{TLBI}}$',
    'err4': '$HASVD_{{TLAI}}$',
    'eps_self': 'Reference'
}
# Out:
# /tmp/ipykernel_115763/2606198139.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   error_df['eps_self'] = error_df['eps']

# %%
rank_df=df[['omega','eps','r','r0','r1','r2','r3','r4', 'r_true']]

# Define new labels for the plot
label_map_2 = {
    'r': '$SVD_{{gesdd}}$',
    'r0': '$HASVD_{{dist}}$',
    'r1': '$HASVD_{{inc}}$',
    'r2': '$HASVD_{{TLBD}}$',
    'r3': '$HASVD_{{TLBI}}$',
    'r4': '$HASVD_{{TLAI}}$',
    'r_true': 'Reference'
}

# %% [markdown]
# Code

# %%
import matplotlib.pyplot as plt
import numpy as np

# Figure size in inches
width_in = 150 / 25.4  # 150 mm
height_in = width_in * 0.75+0.5  # 4:3 ratio

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": 10,
    "axes.labelsize": 10,
    "legend.fontsize": 8,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "figure.dpi": 300,
})

fig, axs = plt.subplots(2, 2, figsize=(width_in, height_in))
(ax1, ax2), (ax3, ax4) = axs

# Plot styles
markers = ['o', 's', 'd', 's', 'd','p', '*']
colors = ['k', 'g', 'r', 'c', 'm','b', 'k']
linestyles = ['-', ':', ':', '-.', '-.', ':','--']
xlim = [1, 1e-15]
xlabel = r'Prescribed relative error $\epsilon^*$'
ylabel_error = '$\langle\|A-U\Sigma V^T\|_F/\|A\|_F\\rangle$'
ylabel_rank = '$\langle\\mathrm{rank}(U\Sigma V^T)\\rangle$'

# Plot error (top row)
for ax, omega in [(ax1, 0.1), (ax2, 0.9)]:
    for i, col in enumerate(['err', 'err0', 'err1', 'err2', 'err3','err4', 'eps_self']):
        marker = None if col == 'eps_self' else markers[i % len(markers)]
        error_df[error_df["omega"] == omega].plot(
            x='eps', y=col, ax=ax,
            label=label_map[col],
            color=colors[i], linestyle=linestyles[i],
            marker=marker
        )
    ax.set_title(rf"$\omega={omega}$")
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlim(xlim)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel_error)
    ax.get_legend().remove()

# Plot rank (bottom row)
for ax, omega in [(ax3, 0.1), (ax4, 0.9)]:
    for i, col in enumerate(['r', 'r0', 'r1', 'r2', 'r3','r4', 'r_true']):
        marker = None if col == 'r_true' else markers[i % len(markers)]
        rank_df[rank_df["omega"] == omega].plot(
            x='eps', y=col, ax=ax,
            label=label_map_2[col],
            color=colors[i], linestyle=linestyles[i],
            marker=marker
        )
    ax.set_title(rf"$\omega={omega}$")
    ax.set_xscale('log')
    ax.set_xlim(xlim)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel_rank)
    ax.get_legend().remove()

# Shared legend above all plots
handles, labels = ax1.get_legend_handles_labels()

ax1.text(-0.1, 1.1, '(a)', transform=ax1.transAxes, fontsize=10, va='top', ha='right')
ax2.text(-0.1, 1.1, '(b)', transform=ax2.transAxes, fontsize=10, va='top', ha='right')
ax3.text(-0.1, 1.1, '(c)', transform=ax3.transAxes, fontsize=10, va='top', ha='right')
ax4.text(-0.1, 1.1, '(d)', transform=ax4.transAxes, fontsize=10, va='top', ha='right')

# Adjust layout
fig.tight_layout()
fig.subplots_adjust(top=0.85)  # Leave room for legend
fig.legend(handles, labels, loc='upper center', ncol=3, bbox_to_anchor=(0.5, 1.01))

# Save figure
fig.savefig("hankel-error-rank-lrf42.pdf", format="pdf", dpi=300, transparent=True)
# fig.savefig("hankel-error-rank-fid.pgf")  # Optional

plt.close(fig)
# Out:
# <>:28: SyntaxWarning: invalid escape sequence '\l'
# <>:29: SyntaxWarning: invalid escape sequence '\l'
# <>:28: SyntaxWarning: invalid escape sequence '\l'
# <>:29: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_115763/28587290.py:28: SyntaxWarning: invalid escape sequence '\l'
#   ylabel_error = '$\langle\|A-U\Sigma V^T\|_F/\|A\|_F\\rangle$'
# /tmp/ipykernel_115763/28587290.py:29: SyntaxWarning: invalid escape sequence '\l'
#   ylabel_rank = '$\langle\\mathrm{rank}(U\Sigma V^T)\\rangle$'

# %%
for i, col in enumerate(['err','err_naive_0','err_tight_0','err_naive_1','err_tight_1',"eps_self"]):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax2 = filtered_df.plot(
        x='eps',
        y=col,
        ax=ax2,
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i]
    )

ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_xlim([1e-1,1e-3])
ax2.set_ylim([1e-4,2e-1])
ax2.set_xlabel(None)
ax2.get_legend().remove()

for i, col in enumerate(['err','err_naive_0','err_tight_0','err_naive_1','err_tight_1',"eps_self"]):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax3 = filtered_df.plot(
        x='eps',
        y=col,
        ax=ax3,
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i]
    )

ax3.set_yscale('log')
ax3.set_xscale('log')
ax3.set_xlim([1e-4,1e-10])
ax3.set_ylim([1e-15,1e-14])
ax3.set_xlabel(None)
ax3.get_legend().remove()

# %% [markdown]
# ## Rank revealing properties

# %% [markdown]
# Data filter

# %%
omega=0.01

filtered_df= df[(df["omega"]==omega)]
filtered_df=filtered_df[['eps','rk','rk_naive_0','rk_tight_0','rk_naive_1','rk_tight_1']]

# Define new labels for the plot
label_map = {
    'rk': 'LAPACK gesdd',
    'rk_naive_0': 'Distributed Naive',
    'rk_tight_0': 'Distributed Tight',
    'rk_naive_1': 'Incremental Naive',
    'rk_tight_1': 'Incremental Tight',
}

# Define styles
markers = ['o', 's', 'd', 's', 'd', '*']
colors = ['k', 'g', 'r', 'c', 'm', 'k']
linestyles = ['-', ':', ':','-.','-.', '--']

ax=None

for i, col in enumerate(['rk','rk_naive_0','rk_tight_0','rk_naive_1','rk_tight_1']):
    marker = markers[i % len(markers)]
    ax = filtered_df.plot(
        x='eps',
        marker= marker,
        y=col,
        ax=ax,
        label=label_map[col],
        color=colors[i % len(colors)],
        linestyle=linestyles[i]
    )

ax.set_xscale('log')
ax.set_xlim([1e-1,1e-5])
ax.set_xlabel('Prescribed error $\epsilon*$')
ax.set_ylabel('Mean matrix rank')
# Out:
# <>:36: SyntaxWarning: invalid escape sequence '\e'
# <>:36: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipykernel_142229/2083392150.py:36: SyntaxWarning: invalid escape sequence '\e'
#   ax.set_xlabel('Prescribed error $\epsilon*$')
# Text(0, 0.5, 'Mean matrix rank')

# %% [markdown]
# ## Control parameter behavior

# %%
# Import the data
df = pd.read_csv('general_error_rank_data_bench_2.csv')

# %%
filtered_df=df[['eps','omega','rk','err','err_tight_0','err_tight_1','rk_tight_0','rk_tight_1']]

markers = ['1', '2', '3', '4', '+']
colors = ['b','g', 'r', 'c', 'm',]
linestyles = [ ':', '-.']

fig2=plt.figure(figsize=(12, 4))
fig2.supxlabel('Prescribed $\epsilon*$')
ax4 = fig2.add_subplot(1,2,1)
ax5 = fig2.add_subplot(1,2,2)

for i, omega in enumerate(pd.unique(filtered_df['omega'])):
    plot_df = filtered_df[(filtered_df["omega"]==omega)]
    plot_df = plot_df[['eps','err_tight_1']]
    ax4 = plot_df.plot(
        x='eps',
        y='err_tight_1',
        marker=markers[i],
        ax=ax4,
        label="$\omega="+str(omega)+"$",
        color=colors[i],
        linestyle=linestyles[i%2]
    )
    
plot_df = filtered_df[(filtered_df["omega"]==0.1)]
ax4 = plot_df.plot(
        x='eps',
        y='err',
        label="LAPACK gesdd",
        ax=ax4,
        color='k',
        linestyle='-'
    )
    
ax4.set_yscale('log')
ax4.set_xscale('log')
ax4.set_xlabel(None)
ax4.set_xlim([4e-2,4e-4])
ax4.get_legend().remove()
ax4.set_ylabel("Mean Frobenius Error")

for i, omega in enumerate(pd.unique(filtered_df['omega'])):
    plot_df = filtered_df[(filtered_df["omega"]==omega)]
    plot_df = plot_df[['eps','rk_tight_1']]
    ax5 = plot_df.plot(
        x='eps',
        y='rk_tight_1',
        marker=markers[i],
        ax=ax5,
        label="$\omega="+str(omega)+"$",
        color=colors[i],
        linestyle=linestyles[i%2]
    )
    
plot_df = filtered_df[(filtered_df["omega"]==0.1)]
ax5 = plot_df.plot(
        x='eps',
        y='rk',
        label="LAPACK gesdd",
        ax=ax5,
        color='k',
        linestyle='-'
    )

ax5.set_xlim([4e-2,4e-4])    
ax5.set_xscale('log')
ax5.set_xlabel(None)
ax5.set_ylabel("Mean matrix rank")
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\e'
# <>:20: SyntaxWarning: invalid escape sequence '\o'
# <>:50: SyntaxWarning: invalid escape sequence '\o'
# <>:8: SyntaxWarning: invalid escape sequence '\e'
# <>:20: SyntaxWarning: invalid escape sequence '\o'
# <>:50: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_176789/2902925739.py:8: SyntaxWarning: invalid escape sequence '\e'
#   fig2.supxlabel('Prescribed $\epsilon*$')
# /tmp/ipykernel_176789/2902925739.py:20: SyntaxWarning: invalid escape sequence '\o'
#   label="$\omega="+str(omega)+"$",
# /tmp/ipykernel_176789/2902925739.py:50: SyntaxWarning: invalid escape sequence '\o'
#   label="$\omega="+str(omega)+"$",
# Text(0, 0.5, 'Mean matrix rank')
